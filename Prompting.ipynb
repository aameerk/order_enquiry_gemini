# %%
# !pip install -U -q "google-generativeai>=0.7.2"

# %%
import google.generativeai as genai

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')

# %%
model = genai.GenerativeModel('models/gemini-1.5-flash')
response = model.generate_content('Can you explain the tasks involved in order enquiry?')

# %%
print(response.text)
# Out:
# The tasks involved in order enquiry management can be broken down into several key stages, and the specifics will vary depending on the size and type of business. However, generally, they include:
#
# **1. Receiving the Enquiry:**
#
# * **Identifying the source:** Determining how the enquiry arrived (phone, email, online form, portal, etc.). This helps track enquiry origins and effectiveness of marketing efforts.
# * **Recording the enquiry:**  Capturing all relevant information accurately and completely.  This typically includes customer details (name, contact information, company), product details (item number, description, quantity), delivery requirements (address, timeframe), and any special instructions or requests. Using a CRM system is crucial for efficient recording and tracking.
# * **Acknowledgement:**  Confirming receipt of the enquiry to the customer, setting expectations for response time.
#
# **2. Enquiry Processing:**
#
# * **Checking availability:** Verifying if the requested products are in stock, or if there are lead times for procurement.
# * **Pricing and costing:** Determining the unit price, discounts (if applicable), taxes, and total cost. This may involve consulting price lists, negotiating, or checking for special pricing agreements.
# * **Checking feasibility:** Assessing whether the order can be fulfilled, considering factors like production capacity, logistical capabilities, and any potential constraints.
# * **Preparing quotations/offers:** Creating a formal document outlining the order details, pricing, payment terms, delivery schedule, and other relevant conditions.
#
# **3. Responding to the Enquiry:**
#
# * **Sending the quotation/offer:**  Delivering the prepared document to the customer in a timely and professional manner via the preferred communication method.
# * **Following up:**  Contacting the customer to confirm receipt and answer any questions they may have.  This may involve multiple follow-up attempts.
# * **Handling objections and negotiations:** Addressing any concerns or objections the customer might raise regarding price, delivery, or other aspects of the offer.  This often involves negotiation and finding mutually acceptable solutions.
#
# **4. Order Placement and Confirmation:**
#
# * **Receiving the order:**  Formally accepting the order once the customer accepts the quotation and confirms their requirements.
# * **Order processing and entry:**  Entering the order details into the company's order management system, generating order numbers, and initiating the fulfillment process.
# * **Order confirmation:**  Sending a formal order confirmation to the customer summarizing all agreed-upon details.
#
# **5. Post-Enquiry Activities (depending on the company's structure):**
#
# * **Reporting and analysis:**  Tracking enquiry conversion rates, average order value, and other relevant metrics to improve efficiency and identify areas for improvement.
# * **Customer relationship management (CRM):**  Updating the customer's record in the CRM system with all relevant information about the enquiry and order.
#
#
# These steps outline a general process.  In some cases, steps might be combined or streamlined, particularly for simpler enquiries or those involving regular customers.  In other cases, more complex steps might be needed, especially for large, customized orders.  The use of technology like CRM systems and ERP systems is essential for managing the process effectively, especially for businesses handling a high volume of enquiries.

# %%
import PIL.Image
img = PIL.Image.open('/content/asset/bill_img.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x1024>

# %%
prompt = """ This image contains details on tax invoice cum delivery challan with product price etc. Given the image, describe it as thoroughly
as possible based on what you see in the image, making sure to note all of the product features. Return output in json format:{description: description, features: {feature1, feature2, feature3, etc}} """

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content([prompt, img])
print(response.text)
# Out:
# ```json
# {
#   "description": "This document is a tax invoice cum delivery challan from Dell Exclusive Store, issued to A.J.D. Nanthakumar on March 30, 2019.  The invoice number is DTAM/1060/18-19. The payment method is CARD. The billing address is detailed, including flat number, block number, apartment name, street, city, state, and pin code. The place of supply is Tamil Nadu. The invoice lists five items: a Dell Inspiron laptop, an ADATA SSD, 8GB DDR4 RAM, a Dell Essential Backpack, and a Sandisk Cruzer CZ50 pendrive.  The total amount due is 65000.00, which includes taxes (CGST and SGST).  The invoice includes terms and conditions regarding warranty and service.",
#   "features": {
#     "product1": {
#       "name": "DELL INSPIRON 5570/15/FHD/15-8250U/4GB/1TB/WIN/B560130WI N9 SN-B4Y6YR2",
#       "quantity": 1,
#       "rate": 47466.10,
#       "hsn/sac": 8471
#     },
#     "product2": {
#       "name": "ADATA 256GB M2 SSD SU800 SN-215120063353",
#       "quantity": 1,
#       "rate": 3686.44,
#       "hsn/sac": 8523
#     },
#     "product3": {
#       "name": "8GB DDR4 LAPTOP RAM SN-GBSH3562",
#       "quantity": 1,
#       "rate": 2991.53,
#       "hsn/sac": 8473
#     },
#     "product4": {
#       "name": "Dell Essential Back Pack SN-GBSH3010",
#       "quantity": 1,
#       "rate": 762.71,
#       "hsn/sac": 42022290
#     },
#     "product5": {
#       "name": "Sandisk Cruzer CZ50 16gb Pendrive SN-GBSH2797",
#       "quantity": 1,
#       "rate": 177.97,
#       "hsn/sac": 8523
#     },
#     "total_before_tax": 55084.75,
#     "cgst": 4957.63,
#     "sgst": 4957.63,
#     "total": 65000.00,
#     "gst_rate": 18.00,
#     "invoice_number": "DTAM/1060/18-19",
#     "invoice_date": "30-Mar-2019",
#     "payment_method": "CARD",
#     "billing_address": "A.J.D. NANTHAKUMAR\nFLAT NO.1B, BLOCK NO.5, NATWEST AURA APARTMENTS,\nREVATHIPURAM, URAPAKKAM,\nCHENNAI, TamilNadu, 603210.",
#     "buyer_gst_no": "7810032033",
#     "state_name": "Tamil Nadu",
#     "place_of_supply": "Tamil Nadu"
#   }
# }
# ```
